# %%
file1 = open('/Users/YeungYathin/Desktop/创新实践/复现代码/PSO/DPSO_TEST/OUTPUT_0/MQ1_result.txt', 'r')
file2 = open('/Users/YeungYathin/Desktop/创新实践/复现代码/PSO/DPSO_TEST/OUTPUT_2/MQ1_result.txt', 'r')
lines1 = file1.readlines()
lines2 = file2.readlines()

# %%
import matplotlib.pyplot as plt
import numpy as np

opt = lines1[1].strip().split()[1]
x = np.arange(1,250)  # 生成包含0到249的一维数组
lst1 = []
lst2 = []
for gen in range(1,250):
    lst1.append(float(lines1[3+gen].split()[1]))
for gen in range(1,250):
    lst2.append(float(lines2[3+gen].split()[1]))
y1 = np.array(lst1)
y2 = np.array(lst2)

plt.plot(x,y1)
plt.plot(x,y2)
# plt.gca().invert_yaxis()

plt.show()
